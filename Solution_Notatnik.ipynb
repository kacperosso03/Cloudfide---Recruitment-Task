# %% [markdown]
# #Kacper Boruta - Recruitment Task for CLoudfide
# To complete this task I got simple dataset of coffee shop to create new virtual column

# %%
import pandas as pd

# %%
df = pd.read_csv("Coffee_Shop_Sales.csv", sep = ";", decimal = ",")
df = df[["transaction_id", "store_id", "transaction_qty", "unit_price"]]
print(df.head(20))
# Out:
#     transaction_id  store_id  transaction_qty  unit_price
# 0                1         5                2        3.00
# 1                2         5                2        3.10
# 2                3         5                2        4.50
# 3                4         5                1        2.00
# 4                5         5                2        3.10
# 5                6         5                1        3.00
# 6                7         5                1        2.00
# 7                8         5                2        2.00
# 8                9         5                1        4.25
# 9               10         5                2        3.50
# 10              11         5                1        2.55
# 11              12         5                2        3.50
# 12              13         5                1        3.00
# 13              14         5                1        3.10
# 14              15         5                2        3.00
# 15              16         5                2        3.00
# 16              17         5                1        3.75
# 17              18         8                1        2.50
# 18              19         8                2        4.50
# 19              20         8                1        4.75

# %%
def add_virtual_column(df: pd.DataFrame, role: str, new_column: str ) -> pd.DataFrame:
    #validation of new column name
    if not all(c.isalpha() or c == "_" for c in new_column):
        return pd.DataFrame([])

    #validation of role
    allowed_chars = set("abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789_ +-*")
    if not all(c in allowed_chars for c in role):
        return pd.DataFrame([])

    #check if every column in role exists in dataframe and is correct
    tokens = role.replace("+"," ").replace("-"," ").replace("*"," ").split()
    for token in tokens:
        if not token.replace("_","").isdigit():
            if not all(c.isalpha() or c == "_" for c in token):
                return pd.DataFrame([])
            if token not in df.columns:
                return pd.DataFrame([])

    #new column
    try:
        df = df.copy()
        df[new_column] = df.eval(role)
    except Exception:
        return pd.DataFrame([])

    return df

# %%
add_virtual_column(df,"transaction_qty*unit_price","total_price")
# Out:
#         transaction_id  store_id  transaction_qty  unit_price  total_price
# 0                    1         5                2        3.00         6.00
# 1                    2         5                2        3.10         6.20
# 2                    3         5                2        4.50         9.00
# 3                    4         5                1        2.00         2.00
# 4                    5         5                2        3.10         6.20
# ...                ...       ...              ...         ...          ...
# 149111          149452         8                2        2.50         5.00
# 149112          149453         8                2        3.00         6.00
# 149113          149454         8                1        3.00         3.00
# 149114          149455         8                1        3.75         3.75
# 149115          149456         8                2        0.80         1.60
#
# [149116 rows x 5 columns]
